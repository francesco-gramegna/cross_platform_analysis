# %%
# ============================================================
# RQ2a: Platform x Category Independence
# Run two datasets in parallel:
#   - Dataset A: 2022 IG vs YouTube (deduped by mode of category)
#   - Dataset B: 2024 IG vs TikTok (no dedup needed)
# ============================================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency

DATA_PATH = "../../4 - ER unified/finalData_with_er.csv"
df = pd.read_csv(DATA_PATH)
# Plot style
plt.rcParams["font.sans-serif"] = ["Arial", "Helvetica", "DejaVu Sans"]
plt.rcParams["axes.unicode_minus"] = False
sns.set_style("whitegrid")
# Out:
# /var/folders/0g/pbpqnp6j47d2_qcp9yhz87ch0000gn/T/ipykernel_42945/3846460153.py:14: DtypeWarning: Columns (5,11,12,13,14,15,23,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(DATA_PATH)

# %%
# ============================================================
# Step 1: Prepare two datasets
# ============================================================

# ---------- Dataset A: 2022 IG vs YouTube (dedup by mode) ----------
df_22_raw = df[
    (df["_year"] == 2022) &
    (df["_platform"].isin(["instagram", "youtube"])) &
    (df["category_unified"].notna()) &
    (~df["category_unified"].isin(["Other", "UNMAPPED"]))
].copy()


def mode_first(s):
    """
    Return the first mode of a series.
    If multiple modes (ties), returns the alphabetically first one.
    Returns np.nan if the series is empty.
    """
    m = s.mode()
    return m.iloc[0] if len(m) > 0 else np.nan


# Step 1a: Diagnose category consistency across months for each account
# i.e., how many (platform, handle) accounts have >1 unique category across months?
consistency = (
    df_22_raw.groupby(["_platform", "handle"])["category_unified"]
    .nunique()
    .reset_index(name="n_unique_categories")
)
inconsistent = consistency[consistency["n_unique_categories"] > 1]

print("=== 2022 category consistency check across months ===")
print(f"Total unique (platform, handle) pairs: {len(consistency):,}")
print(f"Accounts with >1 unique category across months: {len(inconsistent):,} "
      f"({len(inconsistent)/len(consistency)*100:.2f}%)")
print(f"\nDistribution of n_unique_categories per account:")
print(consistency["n_unique_categories"].value_counts().sort_index())

# Step 1b: Dedup by taking the mode of category per (platform, handle)
df_22 = (
    df_22_raw.groupby(["_platform", "handle"], as_index=False)
    .agg({
        "category_unified": mode_first,
        # Keep one country value per account (mode also)
        "_country": mode_first,
        # Keep followers as max (most recent / largest observed)
        "followers": "max",
    })
)

print(f"\n=== Dataset A: 2022 IG vs YouTube (after mode dedup) ===")
print(f"Rows before dedup: {len(df_22_raw):,}")
print(f"Rows after dedup:  {len(df_22):,}")
print(f"\nAccounts per platform:")
print(df_22["_platform"].value_counts())

# ---------- Dataset B: 2024 IG vs TikTok (no dedup needed) ----------
df_24 = df[
    (df["_year"] == 2024) &
    (df["_platform"].isin(["instagram", "tiktok"])) &
    (df["category_unified"].notna()) &
    (~df["category_unified"].isin(["Other", "UNMAPPED"]))
].copy()

print(f"\n=== Dataset B: 2024 IG vs TikTok ===")
print(f"Total rows: {len(df_24):,}")
print(f"\nAccounts per platform:")
print(df_24["_platform"].value_counts())
# Out:
# === 2022 category consistency check across months ===
# Total unique (platform, handle) pairs: 2,342
# Accounts with >1 unique category across months: 188 (8.03%)
#
# Distribution of n_unique_categories per account:
# n_unique_categories
# 1    2154
# 2     187
# 3       1
# Name: count, dtype: int64
#
# === Dataset A: 2022 IG vs YouTube (after mode dedup) ===
# Rows before dedup: 7,903
# Rows after dedup:  2,342
#
# Accounts per platform:
# _platform
# instagram    1363
# youtube       979
# Name: count, dtype: int64
#
# === Dataset B: 2024 IG vs TikTok ===
# Total rows: 7,601
#
# Accounts per platform:
# _platform
# instagram    5282
# tiktok       2319
# Name: count, dtype: int64

# %%
# ============================================================
# Step 2: Core RQ2a analysis function
# Input: a filtered dataframe + a label
# Output: dict with contingency table, chi2, Cramer's V, residuals
# ============================================================

def run_rq2a_analysis(df_sub, title):
    """Run a complete RQ2a analysis on a filtered dataframe."""
    print(f"\n{'='*60}")
    print(f"RQ2a analysis: {title}")
    print(f"{'='*60}")
    
    # 1. Contingency table (observed frequencies)
    ct = pd.crosstab(df_sub["_platform"], df_sub["category_unified"])
    print(f"\n--- Contingency table (observed) ---")
    print(ct)
    
    # 2. Row-proportions (for stacked bar chart)
    ct_prop = ct.div(ct.sum(axis=1), axis=0)
    print(f"\n--- Row-proportions (%) ---")
    print((ct_prop * 100).round(2))
    
    # 3. Chi-square test of independence
    chi2, p, dof, expected = chi2_contingency(ct)
    n = ct.values.sum()
    
    # 4. Cramer's V (effect size, sample-size invariant)
    # V = sqrt(chi2 / (n * min(r-1, c-1)))
    cramers_v = np.sqrt(chi2 / (n * (min(ct.shape) - 1)))
    
    print(f"\n--- Test results ---")
    print(f"chi2 = {chi2:.2f}")
    print(f"df   = {dof}")
    print(f"p    = {p:.2e}")
    print(f"n    = {n:,}")
    print(f"Cramer's V = {cramers_v:.4f}")
    
    # Cohen's convention for Cramer's V (depends on df* = min(r-1, c-1))
    df_star = min(ct.shape) - 1
    if df_star == 1:
        thresholds = (0.10, 0.30, 0.50)
    elif df_star == 2:
        thresholds = (0.07, 0.21, 0.35)
    else:
        thresholds = (0.06, 0.17, 0.29)
    
    if cramers_v < thresholds[0]:
        strength = "negligible"
    elif cramers_v < thresholds[1]:
        strength = "weak"
    elif cramers_v < thresholds[2]:
        strength = "moderate"
    else:
        strength = "strong"
    print(f"Effect size (df*={df_star}): {strength}")
    
    # 5. Expected frequency validity check (>= 5 for chi-square approximation)
    expected_df = pd.DataFrame(expected, index=ct.index, columns=ct.columns)
    print(f"\n--- Expected frequency validity check ---")
    print(f"Min expected frequency: {expected.min():.2f}")
    pct_low = (expected < 5).sum() / expected.size * 100
    print(f"Cells with expected < 5: {(expected < 5).sum()} / {expected.size} ({pct_low:.1f}%)")
    if pct_low > 20:
        print("WARNING: >20% cells with expected < 5, chi-square approximation may be unreliable")
    else:
        print("OK: expected frequency check passed")
    
    # 6. Standardized residuals (Pearson)
    # r = (observed - expected) / sqrt(expected)
    std_residuals = (ct - expected_df) / np.sqrt(expected_df)
    print(f"\n--- Standardized residuals ---")
    print(std_residuals.round(2))
    print("(|r| > 2 indicates significant deviation from independence)")
    
    return {
        "ct": ct,
        "ct_prop": ct_prop,
        "chi2": chi2,
        "p": p,
        "dof": dof,
        "n": n,
        "cramers_v": cramers_v,
        "strength": strength,
        "expected": expected_df,
        "std_residuals": std_residuals,
    }


# Run both datasets
res_22 = run_rq2a_analysis(df_22, "2022 IG vs YouTube (mode-deduped)")
res_24 = run_rq2a_analysis(df_24, "2024 IG vs TikTok")
# Out:
# ============================================================
# RQ2a analysis: 2022 IG vs YouTube (mode-deduped)
# ============================================================
#
# --- Contingency table (observed) ---
# category_unified  Beauty&Fashion  Entertainment  Knowledge&Info  Lifestyle  \
# _platform
# instagram                    112            386              28        295
# youtube                       10            282             112        132
#
# category_unified  Music  Sports  Tech&Gaming
# _platform
# instagram           331     194           17
# youtube             324      15          104
#
# --- Row-proportions (%) ---
# category_unified  Beauty&Fashion  Entertainment  Knowledge&Info  Lifestyle  \
# _platform
# instagram                   8.22          28.32            2.05      21.64
# youtube                     1.02          28.80           11.44      13.48
#
# category_unified  Music  Sports  Tech&Gaming
# _platform
# instagram         24.28   14.23         1.25
# youtube           33.09    1.53        10.62
#
# --- Test results ---
# chi2 = 377.21
# df   = 6
# p    = 2.21e-78
# n    = 2,342
# Cramer's V = 0.4013
# Effect size (df*=1): moderate
#
# --- Expected frequency validity check ---
# Min expected frequency: 50.58
# Cells with expected < 5: 0 / 14 (0.0%)
# OK: expected frequency check passed
#
# --- Standardized residuals ---
# category_unified  Beauty&Fashion  Entertainment  Knowledge&Info  Lifestyle  \
# _platform
# instagram                   4.87          -0.14           -5.92       2.95
# youtube                    -5.74           0.17            6.99      -3.48
#
# category_unified  Music  Sports  Tech&Gaming
# _platform
# instagram         -2.57    6.56        -6.37
# youtube            3.03   -7.74         7.51
# (|r| > 2 indicates significant deviation from independence)
#
# ============================================================
# RQ2a analysis: 2024 IG vs TikTok
# ============================================================
#
# --- Contingency table (observed) ---
# category_unified  Beauty&Fashion  Entertainment  Knowledge&Info  Lifestyle  \
# _platform
# instagram                   1624            461             622        338
# tiktok                       417            149             229        354
#
# category_unified  Music  Sports  Tech&Gaming
# _platform
# instagram          1159     928          150
# tiktok              859     174          137
#
# --- Row-proportions (%) ---
# category_unified  Beauty&Fashion  Entertainment  Knowledge&Info  Lifestyle  \
# _platform
# instagram                  30.75           8.73           11.78       6.40
# tiktok                     17.98           6.43            9.87      15.27
#
# category_unified  Music  Sports  Tech&Gaming
# _platform
# instagram         21.94   17.57         2.84
# tiktok            37.04    7.50         5.91
#
# --- Test results ---
# chi2 = 543.94
# df   = 6
# p    = 2.85e-114
# n    = 7,601
# Cramer's V = 0.2675
# Effect size (df*=1): weak
#
# --- Expected frequency validity check ---
# Min expected frequency: 87.56
# Cells with expected < 5: 0 / 14 (0.0%)
# OK: expected frequency check passed
#
# --- Standardized residuals ---
# category_unified  Beauty&Fashion  Entertainment  Knowledge&Info  Lifestyle  \
# _platform
# instagram                   5.46           1.80            1.26      -6.52
# tiktok                     -8.24          -2.72           -1.90       9.83
#
# category_unified  Music  Sports  Tech&Gaming
# _platform
# instagram         -6.50    5.86        -3.50
# tiktok             9.81   -8.85         5.28
# (|r| > 2 indicates significant deviation from independence)

# %%
# ============================================================
# Step 3: Visualization 1 - Stacked bar chart of category share
# ============================================================

# Unify category order across both datasets (sorted by total frequency)
all_cats = sorted(
    set(res_22["ct"].columns) | set(res_24["ct"].columns),
    key=lambda c: -(
        res_22["ct"].get(c, pd.Series(0)).sum() +
        res_24["ct"].get(c, pd.Series(0)).sum()
    ),
)

# Color palette (colorblind-friendly)
colors = sns.color_palette("Set2", n_colors=len(all_cats))
cat_color_map = dict(zip(all_cats, colors))


def plot_stacked(ax, res, title):
    """Draw a horizontal stacked percentage bar for one platform."""
    ct_prop = res["ct_prop"]
    left = np.zeros(len(ct_prop))
    for cat in all_cats:
        if cat in ct_prop.columns:
            vals = ct_prop[cat].values
            ax.barh(
                ct_prop.index, vals, left=left,
                color=cat_color_map[cat], label=cat,
                edgecolor="white", linewidth=0.5
            )
            for j, v in enumerate(vals):
                if v > 0.05:
                    ax.text(
                        left[j] + v / 2, j, f"{v*100:.0f}%",
                        ha="center", va="center", fontsize=10,
                        color="white", fontweight="bold"
                    )
            left += vals
    ax.set_xlim(0, 1)
    ax.set_title(title)
    ax.set_xlabel("Proportion")


# --- Figure 1: 2022 IG vs YouTube (statistics removed) ---
fig1, ax1 = plt.subplots(figsize=(12, 3))
plot_stacked(ax1, res_22, "Category mix by platform — 2022 (Instagram vs YouTube)")
handles, labels = ax1.get_legend_handles_labels()
fig1.legend(handles, labels, loc="center right", bbox_to_anchor=(1.12, 0.5), fontsize=9)
plt.tight_layout()
plt.savefig("../plots/rq2a_stacked_bars_2022.png", dpi=150, bbox_inches="tight")
plt.show()

# --- Figure 2: 2024 IG vs TikTok (statistics removed) ---
fig2, ax2 = plt.subplots(figsize=(12, 3))
plot_stacked(ax2, res_24, "Category mix by platform — 2024 (Instagram vs TikTok)")
handles, labels = ax2.get_legend_handles_labels()
fig2.legend(handles, labels, loc="center right", bbox_to_anchor=(1.12, 0.5), fontsize=9)
plt.tight_layout()
plt.savefig("../plots/rq2a_stacked_bars_2024.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
# ============================================================
# Step 4: Visualization 2 - Standardized residuals heatmap
# ============================================================

# Shared color scale across both panels for visual comparability
vmax = max(
    np.abs(res_22["std_residuals"].values).max(),
    np.abs(res_24["std_residuals"].values).max(),
)

# --- Figure 1: 2022 IG vs YouTube ---
fig1, ax1 = plt.subplots(figsize=(8, 3))
sns.heatmap(
    res_22["std_residuals"], annot=True, fmt=".1f",
    cmap="RdBu_r", center=0, vmin=-vmax, vmax=vmax,
    cbar_kws={"label": "Standardized residual"},
    ax=ax1, linewidths=0.5, linecolor="white",
)
ax1.set_title(
    f"2022 IG vs YouTube\nchi2={res_22['chi2']:.1f} | p={res_22['p']:.2e} | V={res_22['cramers_v']:.3f}\n"
    "red = overrepresented, blue = underrepresented"
)
ax1.set_xlabel("")
ax1.set_ylabel("")
ax1.tick_params(axis="x", rotation=30)
plt.tight_layout()
plt.savefig("../plots/rq2a_residuals_2022.png", dpi=150, bbox_inches="tight")
plt.show()

# --- Figure 2: 2024 IG vs TikTok ---
fig2, ax2 = plt.subplots(figsize=(8, 3))
sns.heatmap(
    res_24["std_residuals"], annot=True, fmt=".1f",
    cmap="RdBu_r", center=0, vmin=-vmax, vmax=vmax,
    cbar_kws={"label": "Standardized residual"},
    ax=ax2, linewidths=0.5, linecolor="white",
)
ax2.set_title(
    f"2024 IG vs TikTok\nchi2={res_24['chi2']:.1f} | p={res_24['p']:.2e} | V={res_24['cramers_v']:.3f}\n"
    "red = overrepresented, blue = underrepresented"
)
ax2.set_xlabel("")
ax2.set_ylabel("")
ax2.tick_params(axis="x", rotation=30)
plt.tight_layout()
plt.savefig("../plots/rq2a_residuals_2024.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
# ============================================================
# Step 5: Side-by-side summary + signature categories
# ============================================================

summary = pd.DataFrame({
    "Dataset": ["2022 IG vs YouTube", "2024 IG vs TikTok"],
    "n": [res_22["n"], res_24["n"]],
    "chi2": [f"{res_22['chi2']:.1f}", f"{res_24['chi2']:.1f}"],
    "df": [res_22["dof"], res_24["dof"]],
    "p-value": [f"{res_22['p']:.2e}", f"{res_24['p']:.2e}"],
    "Cramer's V": [f"{res_22['cramers_v']:.4f}", f"{res_24['cramers_v']:.4f}"],
    "Effect": [res_22["strength"], res_24["strength"]],
})

print("\n" + "=" * 70)
print("RQ2a Side-by-side comparison")
print("=" * 70)
print(summary.to_string(index=False))

# Signature categories per platform (|r| > 2 in standardized residuals)
print("\n\n=== Signature categories (|standardized residual| > 2) ===\n")

for label, res in [("2022 IG vs YouTube", res_22), ("2024 IG vs TikTok", res_24)]:
    sr = res["std_residuals"]
    print(f"--- {label} ---")
    for platform in sr.index:
        over = sr.loc[platform][sr.loc[platform] > 2].sort_values(ascending=False)
        under = sr.loc[platform][sr.loc[platform] < -2].sort_values()
        print(f"  {platform}:")
        if len(over) > 0:
            print(f"    Over-represented (signature): {dict(over.round(1))}")
        if len(under) > 0:
            print(f"    Under-represented:           {dict(under.round(1))}")
    print()
# Out:
# ======================================================================
# RQ2a Side-by-side comparison
# ======================================================================
#            Dataset    n  chi2  df   p-value Cramer's V   Effect
# 2022 IG vs YouTube 2342 377.2   6  2.21e-78     0.4013 moderate
#  2024 IG vs TikTok 7601 543.9   6 2.85e-114     0.2675     weak
#
#
# === Signature categories (|standardized residual| > 2) ===
#
# --- 2022 IG vs YouTube ---
#   instagram:
#     Over-represented (signature): {'Sports': np.float64(6.6), 'Beauty&Fashion': np.float64(4.9), 'Lifestyle': np.float64(2.9)}
#     Under-represented:           {'Tech&Gaming': np.float64(-6.4), 'Knowledge&Info': np.float64(-5.9), 'Music': np.float64(-2.6)}
#   youtube:
#     Over-represented (signature): {'Tech&Gaming': np.float64(7.5), 'Knowledge&Info': np.float64(7.0), 'Music': np.float64(3.0)}
#     Under-represented:           {'Sports': np.float64(-7.7), 'Beauty&Fashion': np.float64(-5.7), 'Lifestyle': np.float64(-3.5)}
#
# --- 2024 IG vs TikTok ---
#   instagram:
#     Over-represented (signature): {'Sports': np.float64(5.9), 'Beauty&Fashion': np.float64(5.5)}
#     Under-represented:           {'Lifestyle': np.float64(-6.5), 'Music': np.float64(-6.5), 'Tech&Gaming': np.float64(-3.5)}
#   tiktok:
#     Over-represented (signature): {'Lifestyle': np.float64(9.8), 'Music': np.float64(9.8), 'Tech&Gaming': np.float64(5.3)}
#     Under-represented:           {'Sports': np.float64(-8.8), 'Beauty&Fashion': np.float64(-8.2), 'Entertainment': np.float64(-2.7)}

# %%
# ============================================================
# Step 6: Correspondence Analysis (CA) on 2022 IG vs YouTube
# ============================================================

# ---- Ensure upstream variables exist (auto-recompute after kernel restart) ----
if 'res_22' not in globals() or 'res_24' not in globals():
    import pandas as pd
    import numpy as np
    from scipy.stats import chi2_contingency

    if 'df' not in globals():
        df = pd.read_csv("../../4 - ER unified/finalData_with_er.csv", low_memory=False)

    def mode_first(s):
        m = s.mode()
        return m.iloc[0] if len(m) > 0 else np.nan

    df_22 = (
        df[
            (df["_year"] == 2022) &
            df["_platform"].isin(["instagram", "youtube"]) &
            df["category_unified"].notna() &
            ~df["category_unified"].isin(["Other", "UNMAPPED"])
        ]
        .groupby(["_platform", "handle"], as_index=False)
        .agg({"category_unified": mode_first, "_country": mode_first, "followers": "max"})
    )
    df_24 = df[
        (df["_year"] == 2024) &
        df["_platform"].isin(["instagram", "tiktok"]) &
        df["category_unified"].notna() &
        ~df["category_unified"].isin(["Other", "UNMAPPED"])
    ].copy()

    def run_rq2a_analysis(df_sub, title):
        ct = pd.crosstab(df_sub["_platform"], df_sub["category_unified"])
        ct_prop = ct.div(ct.sum(axis=1), axis=0)
        chi2, p, dof, expected = chi2_contingency(ct)
        n = ct.values.sum()
        cramers_v = np.sqrt(chi2 / (n * (min(ct.shape) - 1)))
        df_star = min(ct.shape) - 1
        if df_star == 1:
            thresholds = (0.10, 0.30, 0.50)
        elif df_star == 2:
            thresholds = (0.07, 0.21, 0.35)
        else:
            thresholds = (0.06, 0.17, 0.29)
        strength = (
            "negligible" if cramers_v < thresholds[0] else
            "weak"       if cramers_v < thresholds[1] else
            "moderate"   if cramers_v < thresholds[2] else
            "strong"
        )
        expected_df = pd.DataFrame(expected, index=ct.index, columns=ct.columns)
        std_residuals = (ct - expected_df) / np.sqrt(expected_df)
        return {
            "ct": ct, "ct_prop": ct_prop, "chi2": chi2, "p": p, "dof": dof,
            "n": n, "cramers_v": cramers_v, "strength": strength,
            "expected": expected_df, "std_residuals": std_residuals,
        }

    res_22 = run_rq2a_analysis(df_22, "2022 IG vs YouTube (mode-deduped)")
    res_24 = run_rq2a_analysis(df_24, "2024 IG vs TikTok")

import prince  # pip install prince

ct_22 = res_22["ct"]

ca = prince.CA(n_components=1, random_state=42)
ca = ca.fit(ct_22)

print("=== CA on 2022 IG vs YouTube ===")
print(f"Eigenvalue (Dim 1): {ca.eigenvalues_[0]:.4f}")
print(f"Total inertia: {ca.total_inertia_:.4f}")
print(f"Explained inertia: {ca.percentage_of_variance_[0]:.1f}%")
print("  (For a 2-row table, Dim 1 necessarily explains 100% of inertia; this is a mathematical property, not a feature of the data)")

row_coords = ca.row_coordinates(ct_22)
print(f"\nRow coordinates (platforms on Dim 1):")
print(row_coords)

col_coords = ca.column_coordinates(ct_22)
print(f"\nColumn coordinates (categories on Dim 1):")
print(col_coords.sort_values(0))

chi2_from_ca = ca.total_inertia_ * ct_22.values.sum()
print(f"\nSanity check: inertia × n = {chi2_from_ca:.2f}")
print(f"  (should match chi2 = {res_22['chi2']:.2f})")

# ---- Visualization: 1D CA projection plot ----
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.lines import Line2D

fig, ax = plt.subplots(figsize=(12, 4))

# Row points (platforms)
for platform, x in row_coords[0].items():
    ax.scatter(x, 0.3, s=300, c="crimson", marker="s", zorder=3,
               edgecolor="black", linewidth=1.2)
    ax.annotate(platform, (x, 0.3), fontsize=13, fontweight="bold",
                xytext=(0, 18), textcoords="offset points",
                ha="center", color="crimson")

# Column points (categories): sort by x, alternate two y-offsets to avoid label overlap
y_offsets = [-18, -33]
for i, (cat, x) in enumerate(col_coords[0].sort_values().items()):
    ax.scatter(x, -0.3, s=120, c="steelblue", marker="o", zorder=3,
               edgecolor="black", linewidth=0.8)
    ax.annotate(cat, (x, -0.3), fontsize=10,
                xytext=(0, y_offsets[i % 2]), textcoords="offset points",
                ha="center", color="steelblue")

ax.axhline(0, color="gray", linewidth=0.8, linestyle="--", alpha=0.6)
ax.axvline(0, color="gray", linewidth=0.4, linestyle=":", alpha=0.4)

ax.set_xlim(col_coords[0].min() * 1.3, col_coords[0].max() * 1.3)
ax.set_ylim(-0.85, 0.7)
ax.set_yticks([])
ax.set_xlabel(f"CA Dim 1 ({ca.percentage_of_variance_[0]:.1f}% of inertia)", fontsize=11)
ax.set_title(
    f"CA 1D projection: 2022 IG vs YouTube\n"
    f"chi2 = {res_22['chi2']:.1f}, Cramer's V = {res_22['cramers_v']:.3f}, "
    f"n = {ct_22.values.sum()}",
    fontsize=12,
)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)

legend_elements = [
    Line2D([0], [0], marker="s", color="w", markerfacecolor="crimson",
           markersize=12, label="Platform"),
    Line2D([0], [0], marker="o", color="w", markerfacecolor="steelblue",
           markersize=10, label="Category"),
]
ax.legend(handles=legend_elements, loc="upper right")

plt.tight_layout()
plt.savefig("../plots/rq2a_ca_1d_biplot.png", dpi=120, bbox_inches="tight")
plt.show()
# Out:
# === CA on 2022 IG vs YouTube ===
# Eigenvalue (Dim 1): 0.1611
# Total inertia: 0.1611
# Explained inertia: 100.0%
#   (For a 2-row table, Dim 1 necessarily explains 100% of inertia; this is a mathematical property, not a feature of the data)
#
# Row coordinates (platforms on Dim 1):
#                   0
# _platform
# instagram -0.340126
# youtube    0.473536
#
# Column coordinates (categories on Dim 1):
#                          0
# category_unified
# Sports           -0.701997
# Beauty&Fashion   -0.681324
# Lifestyle        -0.220758
# Entertainment     0.008387
# Music             0.155378
# Knowledge&Info    0.774443
# Tech&Gaming       0.895084
#
# Sanity check: inertia × n = 377.21
#   (should match chi2 = 377.21)

# %%
# ============================================================
# Step 7: Correspondence Analysis (CA) on 2024 IG vs TikTok
# ============================================================

ct_24 = res_24["ct"]

ca_24 = prince.CA(n_components=1, random_state=42)
ca_24 = ca_24.fit(ct_24)

print("=== CA on 2024 IG vs TikTok ===")
print(f"Eigenvalue (Dim 1): {ca_24.eigenvalues_[0]:.4f}")
print(f"Total inertia: {ca_24.total_inertia_:.4f}")
print(f"Explained inertia: {ca_24.percentage_of_variance_[0]:.1f}%")

row_coords_24 = ca_24.row_coordinates(ct_24)
print(f"\nRow coordinates (platforms on Dim 1):")
print(row_coords_24)

col_coords_24 = ca_24.column_coordinates(ct_24)
print(f"\nColumn coordinates (categories on Dim 1):")
print(col_coords_24.sort_values(0))

chi2_from_ca_24 = ca_24.total_inertia_ * ct_24.values.sum()
print(f"\nSanity check: inertia × n = {chi2_from_ca_24:.2f}")
print(f"  (should match chi2 = {res_24['chi2']:.2f})")

# ---- Visualization: 1D CA projection plot ----
fig, ax = plt.subplots(figsize=(12, 4))

# Row points (platforms)
for platform, x in row_coords_24[0].items():
    ax.scatter(x, 0.3, s=300, c="crimson", marker="s", zorder=3,
               edgecolor="black", linewidth=1.2)
    ax.annotate(platform, (x, 0.3), fontsize=13, fontweight="bold",
                xytext=(0, 18), textcoords="offset points",
                ha="center", color="crimson")

# Column points (categories): sort by x, alternate two y-offsets to avoid label overlap
y_offsets = [-18, -33]
for i, (cat, x) in enumerate(col_coords_24[0].sort_values().items()):
    ax.scatter(x, -0.3, s=120, c="steelblue", marker="o", zorder=3,
               edgecolor="black", linewidth=0.8)
    ax.annotate(cat, (x, -0.3), fontsize=10,
                xytext=(0, y_offsets[i % 2]), textcoords="offset points",
                ha="center", color="steelblue")

ax.axhline(0, color="gray", linewidth=0.8, linestyle="--", alpha=0.6)
ax.axvline(0, color="gray", linewidth=0.4, linestyle=":", alpha=0.4)

ax.set_xlim(col_coords_24[0].min() * 1.3, col_coords_24[0].max() * 1.3)
ax.set_ylim(-0.85, 0.7)
ax.set_yticks([])
ax.set_xlabel(f"CA Dim 1 ({ca_24.percentage_of_variance_[0]:.1f}% of inertia)", fontsize=11)
ax.set_title(
    f"CA 1D projection: 2024 IG vs TikTok\n"
    f"chi2 = {res_24['chi2']:.1f}, Cramer's V = {res_24['cramers_v']:.3f}, "
    f"n = {ct_24.values.sum()}",
    fontsize=12,
)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)

legend_elements = [
    Line2D([0], [0], marker="s", color="w", markerfacecolor="crimson",
           markersize=12, label="Platform"),
    Line2D([0], [0], marker="o", color="w", markerfacecolor="steelblue",
           markersize=10, label="Category"),
]
ax.legend(handles=legend_elements, loc="upper right")

plt.tight_layout()
plt.savefig("../plots/rq2a_ca_1d_biplot_2024.png", dpi=120, bbox_inches="tight")
plt.show()
# Out:
# === CA on 2024 IG vs TikTok ===
# Eigenvalue (Dim 1): 0.0716
# Total inertia: 0.0716
# Explained inertia: 100.0%
#
# Row coordinates (platforms on Dim 1):
#                   0
# _platform
# instagram -0.177253
# tiktok     0.403729
#
# Column coordinates (categories on Dim 1):
#                          0
# category_unified
# Sports           -0.319683
# Beauty&Fashion   -0.218874
# Entertainment    -0.132109
# Knowledge&Info   -0.078177
# Music             0.261871
# Tech&Gaming       0.374116
# Lifestyle         0.448411
#
# Sanity check: inertia × n = 543.94
#   (should match chi2 = 543.94)
